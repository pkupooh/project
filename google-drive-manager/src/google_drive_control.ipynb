# %%
import pickle
import os
import pandas_gbq
import pandas as pd
from google_auth_oauthlib.flow import Flow, InstalledAppFlow
from googleapiclient.discovery import build
from googleapiclient.http import MediaFileUpload, MediaIoBaseDownload
from google.auth.transport.requests import Request
from datetime import datetime
from googleapiclient import discovery
from google.oauth2 import service_account
from google.cloud import storage
from google.cloud import bigquery
from googleapiclient.discovery import build
from googleapiclient.errors import HttpError

# create folder in google drive test

dev_key_path = "/Users/gowid/Desktop/master/transaction_analysis/config/gowid-gcs-dev_keyfile.json"
prd_key_path = "/Users/gowid/Desktop/master/transaction_analysis/config/gowid-gcs-prd-f069a99a7d10.json"

# sql_path = '/Users/gowid/Desktop/master/cashflow_analysis/sql/'

dev_credentials = service_account.Credentials.from_service_account_file(dev_key_path,scopes=['https://www.googleapis.com/auth/drive','https://www.googleapis.com/auth/bigquery','https://www.googleapis.com/auth/devstorage.full_control'])
prd_credentials = service_account.Credentials.from_service_account_file(prd_key_path,scopes=['https://www.googleapis.com/auth/drive','https://www.googleapis.com/auth/bigquery','https://www.googleapis.com/auth/devstorage.full_control'])

#client 설정
client = storage.Client(credentials = dev_credentials, project = dev_credentials.project_id)
bq_client = bigquery.Client(credentials = dev_credentials, project = dev_credentials.project_id)

# 대상 법인 folder list
sql = f"""
SELECT cast(a1.idxCorp as string) as idxCorp
FROM `gowid-gcs-prd.raw_stream_gowid.CardIssuanceInfo` a1
LEFT JOIN (
            SELECT corp_id
            FROM `gowid-gcs-dev.gowid_credit_report.crm_document_drive` 
)a2
ON a1.idxCorp = cast(a2.corp_id as int64)
WHERE a1.issuanceStatus in ('APPLY','ISSUED')
      AND a1.cardType in ('GOWID')
      AND a2.corp_id is null 
ORDER BY idxCorp
"""

# 데이터 조회 쿼리 실행 결과
query_job = bq_client.query(sql)
df = query_job.to_dataframe()

# list create
corp_list = df['idxCorp'].to_list()
folder_id_list = []
url_list = []
ref_date = []

# create folder function
def create_folder(corp_list):
    google_drive_id = '1Jn0Dg0fSuE_pSKiKTQF6ontnAVinjnzK' # parent folder id
    dev_credentials = service_account.Credentials.from_service_account_file(dev_key_path,scopes=['https://www.googleapis.com/auth/drive','https://www.googleapis.com/auth/bigquery','https://www.googleapis.com/auth/devstorage.full_control','https://www.googleapis.com/auth/cloud-platform'])
    service = discovery.build('drive', 'v3', credentials=dev_credentials)
    try:
        for name_list in corp_list:
            file_metadata = {
                    'name': name_list,
                    'mimeType': 'application/vnd.google-apps.folder'
                    ,'parents' : [google_drive_id]
                }
            file = service.files().create(supportsAllDrives=True, body=file_metadata, fields = "id").execute()
            file_id = file.get("id")
            request_body = {
                'role': 'reader',
                'type': 'anyone'
            }
            response_permission = service.permissions().create(fileId=file_id, body=request_body).execute()

            # Print Sharing URL
            response_share_link = service.files().get(fileId=file_id,fields='webViewLink').execute()
            url = list(response_share_link.values())[0]

            # Remove Sharing Permission
            service.permissions().delete(
                fileId=file_id,
                permissionId='anyoneWithLink'
            ).execute()

            print('Folder id :' + file_id + 'URL : ' + url)

            # append to list
            folder_id_list.append(file_id)
            url_list.append(url)

        return file.get('id')
    except HttpError as error:
        print(F'An error occurred: {error}')
        return None        

#execute function
create_folder(corp_list)


# list to dataframe
drive_table = pd.DataFrame(list(zip(corp_list, folder_id_list, url_list)),columns = ['corp_id','folder_id','drive_url'])
ref_date = datetime.today().strftime('%Y-%m-%d')
drive_table['ref_date'] = ref_date


# dataframe to Bigquery
credentials = service_account.Credentials.from_service_account_file(
dev_key_path, scopes=["https://www.googleapis.com/auth/cloud-platform"],
)

project_id = 'gowid-gcs-dev'

bq_client=bigquery.Client(project='gowid-gcs-dev').from_service_account_json(
            json_credentials_path=dev_key_path)

# Construct a BigQuery client object.
table_id = 'gowid-gcs-dev.gowid_credit_report.crm_document_drive'

drive_table.to_gbq(table_id,project_id ,if_exists='append', credentials = credentials)
# Out:
# Folder id :19ivKxdnq9k6CI18YodbbySP54hAz8uBCURL : https://drive.google.com/drive/folders/19ivKxdnq9k6CI18YodbbySP54hAz8uBC
# Folder id :1t7kb_PfSJmk4jIacKifXyTLuBBjj34X_URL : https://drive.google.com/drive/folders/1t7kb_PfSJmk4jIacKifXyTLuBBjj34X_
# Folder id :1FujtqNRzefWCjbi3FFptxv6UVKVWd4b2URL : https://drive.google.com/drive/folders/1FujtqNRzefWCjbi3FFptxv6UVKVWd4b2
# Folder id :17Fv_7p57H1aLhJlCaNEVdKfTkVIedTstURL : https://drive.google.com/drive/folders/17Fv_7p57H1aLhJlCaNEVdKfTkVIedTst
# Folder id :16ZzvdWITgdX0YGYXQ0Ksk3PVWSl9yV9MURL : https://drive.google.com/drive/folders/16ZzvdWITgdX0YGYXQ0Ksk3PVWSl9yV9M
# Folder id :1DuP5jOVFoM8rSzjtawshtEjvB3lqkAd7URL : https://drive.google.com/drive/folders/1DuP5jOVFoM8rSzjtawshtEjvB3lqkAd7
# Folder id :1a6OkH6lias5X8hS_gsFf-7etz3Zx0MEiURL : https://drive.google.com/drive/folders/1a6OkH6lias5X8hS_gsFf-7etz3Zx0MEi
# Folder id :1Wm1xRsazYmA8l38M_mr9-dY9SesM5jkuURL : https://drive.google.com/drive/folders/1Wm1xRsazYmA8l38M_mr9-dY9SesM5jku
# Folder id :1bHt5cNnkDCnteFu9l8f2sfdRhewp6R7nURL : https://drive.google.com/drive/folders/1bHt5cNnkDCnteFu9l8f2sfdRhewp6R7n
# Folder id :16E-BwaDWNbuv0bh0T4BRrOdB9fUxYPXvURL : https://drive.google.com/drive/folders/16E-BwaDWNbuv0bh0T4BRrOdB9fUxYPXv
# Folder id :1Z1fJH9J2ejAFxOagVrrw04C-b4WIrghWURL : https://drive.google.com/drive/folders/1Z1fJH9J2ejAFxOagVrrw04C-b4WIrghW
# Folder id :1Ixll5xs5BB65ldXiffYvWjeXIFlWfLk-URL : https://drive.google.com/drive/folders/1Ixll5xs5BB65ldXiffYvWjeXIFlWfLk-
# Folder id :1ZXwRinnGjtjbZjRSoOuNg2hjsK2yD-ENURL : https://drive.google.com/drive/folders/1ZXwRinnGjtjbZjRSoOuNg2hjsK2yD-EN
# Folder id :18W68U0H7C27MOOacCuwRT4RTvp6rm4VRURL : https://drive.google.com/drive/folders/18W68U0H7C27MOOacCuwRT4RTvp6rm4VR
# Folder id :1rbXgV2_KHLC03prfMfpRzRAOEcSjRZR7URL : https://drive.google.com/drive/folders/1rbXgV2_KHLC03prfMfpRzRAOEcSjRZR7
# Folder id :1yENrS-FrxQQ_Ewf-J5aE4tucdHS0HJzlURL : https://drive.google.com/drive/folders/1yENrS-FrxQQ_Ewf-J5aE4tucdHS0HJzl
# Folder id :1kKd692brISilFNquV7FyCveo1qv0TdYeURL : https://drive.google.com/drive/folders/1kKd692brISilFNquV7FyCveo1qv0TdYe
# Folder id :1c2abiLQ7noi4DTWILg-W9RwUO6JO1C4xURL : https://drive.google.com/drive/folders/1c2abiLQ7noi4DTWILg-W9RwUO6JO1C4x
# Folder id :1ib-P6-IobWJe-etLnBNiQiKEtMZjvxunURL : https://drive.google.com/drive/folders/1ib-P6-IobWJe-etLnBNiQiKEtMZjvxun
# Folder id :1pzDEZfLVYbbapzYBA1SSMo7gCICP8niJURL : https://drive.google.com/drive/folders/1pzDEZfLVYbbapzYBA1SSMo7gCICP8niJ
# Folder id :12j9jIKWoFupigvHiOTS440s6ad9pdmvNURL : https://drive.google.com/drive/folders/12j9jIKWoFupigvHiOTS440s6ad9pdmvN
# Folder id :114yTJTVOpF7e-JOIaekWQhD539Cxd5fwURL : https://drive.google.com/drive/folders/114yTJTVOpF7e-JOIaekWQhD539Cxd5fw
# Folder id :1p9d8cgCcZTFN8rQ3sLe1nXArYt1uxpACURL : https://drive.google.com/drive/folders/1p9d8cgCcZTFN8rQ3sLe1nXArYt1uxpAC
# Folder id :1YsofjF5eYOcDziij-7JG-6RhxJf9TxeaURL : https://drive.google.com/drive/folders/1YsofjF5eYOcDziij-7JG-6RhxJf9Txea
# Folder id :1sTq0v29E6HS3pToiU4ZUTmv2LSHQ6p4hURL : https://drive.google.com/drive/folders/1sTq0v29E6HS3pToiU4ZUTmv2LSHQ6p4h
# Folder id :1s-_muLNejytiuKKTFb4msMaYqtj5Z592URL : https://drive.google.com/drive/folders/1s-_muLNejytiuKKTFb4msMaYqtj5Z592
# Folder id :1HtktNrePXrsCzOZx5NnmaJdSWQgv5J9FURL : https://drive.google.com/drive/folders/1HtktNrePXrsCzOZx5NnmaJdSWQgv5J9F
# Folder id :1owmyALZd125Y59s3md3R6n20bdL342z2URL : https://drive.google.com/drive/folders/1owmyALZd125Y59s3md3R6n20bdL342z2
# Folder id :1zlzzuOJzmwURIZ7m4Nc6L-cUhDq7vEYTURL : https://drive.google.com/drive/folders/1zlzzuOJzmwURIZ7m4Nc6L-cUhDq7vEYT
# Folder id :1x81y8_DLJEYemEqMcB3GWHZ28WDknkxLURL : https://drive.google.com/drive/folders/1x81y8_DLJEYemEqMcB3GWHZ28WDknkxL
# Folder id :1-fxN7JLGZiQxN7E7a0EhqGNd0_afY7oTURL : https://drive.google.com/drive/folders/1-fxN7JLGZiQxN7E7a0EhqGNd0_afY7oT
# Folder id :1lCbJ1cwsZXD5Ci4QE1GSEtNiqBtlg0JYURL : https://drive.google.com/drive/folders/1lCbJ1cwsZXD5Ci4QE1GSEtNiqBtlg0JY
# Folder id :1Fc2NOqlrCOrkupsBGpu_DiumPjU2K3huURL : https://drive.google.com/drive/folders/1Fc2NOqlrCOrkupsBGpu_DiumPjU2K3hu
# Folder id :1bYH1mZilBui_ZuuulZ5l3_LBmiftudh4URL : https://drive.google.com/drive/folders/1bYH1mZilBui_ZuuulZ5l3_LBmiftudh4
# Folder id :1kelB4YaSQ0z6m31apvtKl17ygFuIbX5YURL : https://drive.google.com/drive/folders/1kelB4YaSQ0z6m31apvtKl17ygFuIbX5Y
# Folder id :11UE23lfAL7fDK_w_yg8SSQTYRGFvMb_aURL : https://drive.google.com/drive/folders/11UE23lfAL7fDK_w_yg8SSQTYRGFvMb_a
# Folder id :1fnk7cYOmOZsFxLRznP3OQ4gYkd-D8xn6URL : https://drive.google.com/drive/folders/1fnk7cYOmOZsFxLRznP3OQ4gYkd-D8xn6
# Folder id :1cP5E5-bE1-_vfDOkksbL0U1on7Bruh6tURL : https://drive.google.com/drive/folders/1cP5E5-bE1-_vfDOkksbL0U1on7Bruh6t
# Folder id :10gyVs9NJVVlhZanYkkEKU9TlKSNx8vsvURL : https://drive.google.com/drive/folders/10gyVs9NJVVlhZanYkkEKU9TlKSNx8vsv
# Folder id :1DYtWxVifzq2PBpy5uFyKGe8Q9_K1ByduURL : https://drive.google.com/drive/folders/1DYtWxVifzq2PBpy5uFyKGe8Q9_K1Bydu
# Folder id :1fRA61-xknFnDkSPq1YxWoM2qiXsy1MFyURL : https://drive.google.com/drive/folders/1fRA61-xknFnDkSPq1YxWoM2qiXsy1MFy
# Folder id :1CVVApe6KbCBKj6ss07OZXTEOl0toVBJqURL : https://drive.google.com/drive/folders/1CVVApe6KbCBKj6ss07OZXTEOl0toVBJq
# Folder id :1bVAUUpWbuatXSlwknUCrazPkhLltR7umURL : https://drive.google.com/drive/folders/1bVAUUpWbuatXSlwknUCrazPkhLltR7um
# Folder id :11wvm6lGN-kdzw-JfgGDuYu_7ZA876-wMURL : https://drive.google.com/drive/folders/11wvm6lGN-kdzw-JfgGDuYu_7ZA876-wM
# Folder id :1nYrNLmHwrD2ArZsWTUAK0FkTI_qoP3GPURL : https://drive.google.com/drive/folders/1nYrNLmHwrD2ArZsWTUAK0FkTI_qoP3GP
# Folder id :16GDYWEgq2yc6IOsj0MbAecenL8Tc01c_URL : https://drive.google.com/drive/folders/16GDYWEgq2yc6IOsj0MbAecenL8Tc01c_
# Folder id :1Ka9zYY3zfLyTivfJVW-TLHfof20U7tWPURL : https://drive.google.com/drive/folders/1Ka9zYY3zfLyTivfJVW-TLHfof20U7tWP
# 100%|██████████| 1/1 [00:00<00:00, 10131.17it/s]
